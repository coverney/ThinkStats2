# %%
import pandas as pd
import thinkplot
import matplotlib

# %%
df = pd.read_csv('C:/Users/coverney/Desktop/Data Science/Project 2/result.csv')
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (9,10,11,13,14,16,18,19,22,23,24,25,26,33,37,39,40,42,43,44,47,48,49,55,56,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         OrganizationIdentifier                        OrganizationFormalName  \
# 0                      USGS-CT         USGS Connecticut Water Science Center
# 1                      USGS-CT         USGS Connecticut Water Science Center
# 2                      USGS-CT         USGS Connecticut Water Science Center
# 3                      USGS-CT         USGS Connecticut Water Science Center
# 4                      USGS-CT         USGS Connecticut Water Science Center
# 5                      USGS-CT         USGS Connecticut Water Science Center
# 6                      USGS-CT         USGS Connecticut Water Science Center
# 7                      USGS-CT         USGS Connecticut Water Science Center
# 8                      USGS-CT         USGS Connecticut Water Science Center
# 9                      USGS-CT         USGS Connecticut Water Science Center
# 10                     USGS-CT         USGS Connecticut Water Science Center
# ...

# %%
df['CharacteristicName'].value_counts()
# Out:
# Total dissolved solids                                          62169
# Ammonia and ammonium                                            43237
# Specific conductance                                            42414
# Oxygen                                                          41815
# Nitrogen, mixed forms (NH3), (NH4), organic, (NO2) and (NO3)    40804
# pH                                                              40502
# Phosphorus                                                      38703
# Stream flow, instantaneous                                      35442
# Nitrate                                                         35412
# Kjeldahl nitrogen                                               30100
# Organic Nitrogen                                                30055
# Nitrite                                                         28255
# Hydrogen ion                                                    27398
# ...

# %%
df['ResultDetectionConditionText'].head()
# Out:
# 0    Not Detected
# 1    Not Detected
# 2    Not Detected
# 3             NaN
# 4             NaN
# Name: ResultDetectionConditionText, dtype: object

# %%
df['ResultMeasureValue'].head()
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3    5.20
# 4      20
# Name: ResultMeasureValue, dtype: object

# %%
df['ResultMeasure/MeasureUnitCode'].head()
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3       m
# 4    mg/l
# Name: ResultMeasure/MeasureUnitCode, dtype: object

# %%
df_mercury = df[df['CharacteristicName']=='Mercury']
df_mercury['MonitoringLocationIdentifier']
# Out:
# 1009              USGS-01118525
# 2072              USGS-01118525
# 3009              USGS-01118525
# 3170              USGS-01118535
# 3278              USGS-01118535
# 3409              USGS-01118550
# 3518              USGS-01118550
# 3588              USGS-01118620
# 3603              USGS-01118621
# 3618              USGS-01118622
# 5402              USGS-01119375
# 6000              USGS-01119375
# 6506              USGS-01119375
# 47985             USGS-01121000
# 48031             USGS-01121000
# 48307             USGS-01121000
# 49054             USGS-01121330
# 49335             USGS-01121330
# 49611             USGS-01121330
# 50667             USGS-01122001
# 51266             USGS-01122001
# 51763             USGS-01122001
# 55873             USGS-01122500
# 55908             USGS-01122500
# 55915             USGS-01122500
# 57438             USGS-01122500
# 58099             USGS-01122610
# 58697             USGS-01122610
# 59200             USGS-01122610
# ...

# %%
df_mercury['MonitoringLocationIdentifier'].value_counts()
# Out:
# USGS-01184000           137
# USGS-01205500           129
# USGS-01127000            90
# USGS-01122610            79
# USGS-01196530            75
# USGS-01127701            73
# USGS-01125500            65
# USGS-01125520            62
# USGS-01193750            42
# USGS-01208828            26
# USGS-01189000             9
# USGS-01193500             8
# USGS-01196500             7
# USGS-01193050             7
# USGS-01201513             7
# USGS-01208500             6
# USGS-01209700             6
# USGS-01192500             6
# USGS-01127500             5
# USGS-01201485             5
# USGS-01208990             5
# USGS-01208869             5
# USGS-01189995             5
# USGS-01203510             5
# USGS-01201511             5
# USGS-01195490             5
# USGS-01208925             5
# USGS-01196620             5
# USGS-01209901             5
# USGS-01188000             5
#                        ...
# USGS-412322073160301      1
# USGS-01125080             1
# ...

# %%
df_one_mercury = df_mercury[df_mercury['MonitoringLocationIdentifier']=='USGS-01184000']

# %%
df_one_mercury
# Out:
#        OrganizationIdentifier                 OrganizationFormalName  \
# 266758                USGS-CT  USGS Connecticut Water Science Center
# 266855                USGS-CT  USGS Connecticut Water Science Center
# 266856                USGS-CT  USGS Connecticut Water Science Center
# 267593                USGS-CT  USGS Connecticut Water Science Center
# 268988                USGS-CT  USGS Connecticut Water Science Center
# 269133                USGS-CT  USGS Connecticut Water Science Center
# 269162                USGS-CT  USGS Connecticut Water Science Center
# 269234                USGS-CT  USGS Connecticut Water Science Center
# 269449                USGS-CT  USGS Connecticut Water Science Center
# 269450                USGS-CT  USGS Connecticut Water Science Center
# 269722                USGS-CT  USGS Connecticut Water Science Center
# 269723                USGS-CT  USGS Connecticut Water Science Center
# 269855                USGS-CT  USGS Connecticut Water Science Center
# ...

# %%
df_one_mercury['ResultMeasureValue'] = df_one_mercury['ResultMeasureValue'].astype(float)
df_one_mercury['ResultMeasureValue']
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 266758    0.50
# 266855     NaN
# 266856     NaN
# 267593     NaN
# 268988    0.02
# 269133     NaN
# 269162     NaN
# 269234     NaN
# 269449     NaN
# 269450     NaN
# 269722     NaN
# 269723     NaN
# 269855    0.01
# 269957    0.00
# 269958     NaN
# 269959     NaN
# 270160    0.00
# 270161     NaN
# 270162     NaN
# 270425    0.00
# 270426     NaN
# 270427     NaN
# 270571    0.00
# 270572     NaN
# 270573     NaN
# 270760    0.00
# 270761     NaN
# 270762     NaN
# 270950    0.00
# 270951     NaN
#           ...
# 277318    0.40
# 277463    0.10
# 277647     NaN
# 277775    0.90
# ...

# %%
# df_one_mercury['ResultMeasureValue'].fillna(0)
thinkplot.Plot(df_one_mercury['ResultMeasureValue'].dropna())
thinkplot.Show()
